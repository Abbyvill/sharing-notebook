# %%
#imports
#numpy,pandas,scipy,math,matplotlob
import numpy as np
import pandas as pd
import scipy
from math import sqrt
import matplotlib.pyplot as plt

#estimators
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn import linear_model

#model metrics
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.model_selection import cross_val_score

#cross validation
from sklearn.model_selection import train_test_split
#Structured Query Language or SQL to query to database table and retrieve the data into a Pandas dataframe
from sqlalchemy import create_engine
import pymysql
import pandas as pd



# Basics
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pandas_profiling   # will need to install at CLI
import seaborn as sb

# SKLearn
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn import tree
from sklearn.metrics import confusion_matrix
from sklearn import ensemble
from sklearn.datasets import load_digits

# helpers
# %matplotlib inline

# Grahpviz 
from sklearn.externals.six import StringIO 
from IPython.display import Image 
from sklearn.tree import export_graphviz
import pydotplus
import graphviz
# Out:
# C:\anaconda\lib\site-packages\sklearn\externals\six.py:31: FutureWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", FutureWarning)

# %%
#data
rawData = pd.read_csv('Credit Risk Data 3.csv')
rawData.head()
# Out:
#    Unnamed: 0  LIMIT_BAL     SEX   EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  \
# 0           0      20000  female  university         1   24      2      2
# 1           1     120000  female  university         2   26     -1      2
# 2           2      90000  female  university         2   34      0      0
# 3           3      50000  female  university         1   37      0      0
# 4           4      50000    male  university         1   57     -1      0
#
#    PAY_3  PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# 0     -1     -1  ...          0          0          0         0       689
# 1      0      0  ...       3272       3455       3261         0      1000
# 2      0      0  ...      14331      14948      15549      1518      1500
# 3      0      0  ...      28314      28959      29547      2000      2019
# 4     -1      0  ...      20940      19146      19131      2000     36681
#
#    PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# 0         0         0         0         0                     default
# 1      1000      1000         0      2000                     default
# 2      1000      1000      1000      5000                 not default
# 3      1200      1100      1069      1000                 not default
# 4     10000      9000       689       679                 not default
#
# [5 rows x 25 columns]

# %%
rawData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Unnamed: 0                  30000 non-null  int64
#  1   LIMIT_BAL                   30000 non-null  int64
#  2   SEX                         30000 non-null  object
#  3   EDUCATION                   30000 non-null  object
#  4   MARRIAGE                    30000 non-null  int64
#  5   AGE                         30000 non-null  int64
#  6   PAY_0                       30000 non-null  int64
#  7   PAY_2                       30000 non-null  int64
#  8   PAY_3                       30000 non-null  int64
#  9   PAY_4                       30000 non-null  int64
#  10  PAY_5                       30000 non-null  int64
#  11  PAY_6                       30000 non-null  int64
#  12  BILL_AMT1                   30000 non-null  int64
#  13  BILL_AMT2                   30000 non-null  int64
#  14  BILL_AMT3                   30000 non-null  int64
#  15  BILL_AMT4                   30000 non-null  int64
#  16  BILL_AMT5                   30000 non-null  int64
#  17  BILL_AMT6                   30000 non-null  int64
#  18  PAY_AMT1                    30000 non-null  int64
#  19  PAY_AMT2                    30000 non-null  int64
#  20  PAY_AMT3                    30000 non-null  int64
#  21  PAY_AMT4                    30000 non-null  int64
#  22  PAY_AMT5                    30000 non-null  int64
#  23  PAY_AMT6                    30000 non-null  int64
#  24  default payment next month  30000 non-null  object
# dtypes: int64(22), object(3)
# memory usage: 5.7+ MB

# %%
#Dropping "Unnamed: 0" column as it is not needed nor relevant.
rawData.drop(["Unnamed: 0"], axis = 1, inplace = True)
rawData
# Out:
#        LIMIT_BAL     SEX    EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 0          20000  female   university         1   24      2      2     -1
# 1         120000  female   university         2   26     -1      2      0
# 2          90000  female   university         2   34      0      0      0
# 3          50000  female   university         1   37      0      0      0
# 4          50000    male   university         1   57     -1      0     -1
# ...          ...     ...          ...       ...  ...    ...    ...    ...
# 29995     220000    male  high school         1   39      0      0      0
# 29996     150000    male  high school         2   43     -1     -1     -1
# 29997      30000    male   university         2   37      4      3      2
# 29998      80000    male  high school         1   41      1     -1      0
# 29999      50000    male   university         1   46      0      0      0
#
#        PAY_4  PAY_5  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# 0         -1     -2  ...          0          0          0         0       689
# 1          0      0  ...       3272       3455       3261         0      1000
# 2          0      0  ...      14331      14948      15549      1518      1500
# 3          0      0  ...      28314      28959      29547      2000      2019
# 4          0      0  ...      20940      19146      19131      2000     36681
# ...      ...    ...  ...        ...        ...        ...       ...       ...
# 29995      0      0  ...      88004      31237      15980      8500     20000
# 29996     -1      0  ...       8979       5190          0      1837      3526
# 29997     -1      0  ...      20878      20582      19357         0         0
# 29998      0      0  ...      52774      11855      48944     85900      3409
# 29999      0      0  ...      36535      32428      15313      2078      1800
#
#        PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# 0             0         0         0         0                     default
# 1          1000      1000         0      2000                     default
# 2          1000      1000      1000      5000                 not default
# 3          1200      1100      1069      1000                 not default
# 4         10000      9000       689       679                 not default
# ...         ...       ...       ...       ...                         ...
# 29995      5003      3047      5000      1000                 not default
# 29996      8998       129         0         0                 not default
# 29997     22000      4200      2000      3100                     default
# 29998      1178      1926     52964      1804                     default
# 29999      1430      1000      1000      1000                     default
#
# [30000 rows x 24 columns]

# %%
rawData.dtypes
# Out:
# LIMIT_BAL                      int64
# SEX                           object
# EDUCATION                     object
# MARRIAGE                       int64
# AGE                            int64
# PAY_0                          int64
# PAY_2                          int64
# PAY_3                          int64
# PAY_4                          int64
# PAY_5                          int64
# PAY_6                          int64
# BILL_AMT1                      int64
# BILL_AMT2                      int64
# BILL_AMT3                      int64
# BILL_AMT4                      int64
# BILL_AMT5                      int64
# BILL_AMT6                      int64
# PAY_AMT1                       int64
# PAY_AMT2                       int64
# PAY_AMT3                       int64
# PAY_AMT4                       int64
# PAY_AMT5                       int64
# PAY_AMT6                       int64
# default payment next month    object
# dtype: object

# %%
rawData.duplicated().any()
# Out:
# True

# %%
print(rawData[rawData.duplicated()].shape)
rawData[rawData.duplicated()]
# Out:
# (35, 24)
#        LIMIT_BAL     SEX        EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 1980      150000  female  graduate school         1   38      1     -2     -2
# 4585      150000  female  graduate school         1   31      1     -2     -2
# 6022      210000  female  graduate school         2   39      1     -2     -2
# 6466      210000  female       university         1   49      1     -2     -2
# 7319      500000    male  graduate school         1   43      1     -2     -2
# 8320      360000    male       university         1   41      1     -2     -2
# 10250      50000    male       university         2   26      1     -2     -2
# 13106     360000  female  graduate school         1   49      1     -2     -2
# 14294      20000    male       university         2   24      2      2      4
# 15458     160000    male       university         2   28     -2     -2     -2
# 15617     200000  female       university         2   26     -2     -2     -2
# 15685     360000    male  graduate school         2   29      1     -2     -2
# 17032      50000  female  graduate school         2   23      1     -2     -2
# 19114      80000  female       university         1   31     -2     -2     -2
# 19487     180000  female  graduate school         2   28      1     -2     -2
# 19604     110000  female  graduate school         2   31      1     -2     -2
# 19897     100000  female       university         1   49      1     -2     -2
# 20875     230000    male  graduate school         1   39     -1     -1     -1
# 21881     160000  female      high school         2   26     -1     -1     -1
# 22162     360000  female  graduate school         2   29      1     -2     -2
# 23877     200000    male  graduate school         2   30     -2     -2     -2
# 24122     140000    male  graduate school         2   29      1     -2     -2
# 25608     360000  female  graduate school         1   41     -2     -2     -2
# 26249      90000  female  graduate school         2   31      1     -2     -2
# 26805     300000    male  graduate school         2   27     -2     -2     -2
# 27351     210000    male       university         1   39     -1     -1     -1
# 27765      80000  female       university         2   25     -2     -2     -2
# 27928     150000  female  graduate school         2   28      1     -2     -2
# 27966     360000  female  graduate school         2   27      1     -2     -2
# 28228     200000  female  graduate school         1   34      1     -2     -2
# 28779     200000  female  graduate school         1   36      1     -2     -2
# 28983      80000  female      high school         1   42     -2     -2     -2
# 29265     180000    male       university         1   26     -1     -1     -1
# 29823     220000    male  graduate school         1   42      1     -2     -2
# 29909     360000    male  graduate school         2   32     -2     -2     -2
#
#        PAY_4  PAY_5  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# 1980      -2     -2  ...          0          0          0         0         0
# 4585      -2     -2  ...          0          0          0         0         0
# 6022      -2     -2  ...          0          0          0         0         0
# 6466      -2     -2  ...          0          0          0         0         0
# 7319      -2     -2  ...          0          0          0         0         0
# 8320      -2     -2  ...          0          0          0         0         0
# 10250     -2     -2  ...          0          0          0         0         0
# 13106     -2     -2  ...          0          0          0         0         0
# 14294      4      4  ...       1650       1650       1650         0         0
# 15458     -2     -2  ...          0          0          0         0         0
# 15617     -2     -2  ...          0          0          0         0         0
# 15685     -2     -2  ...          0          0          0         0         0
# 17032     -2     -2  ...          0          0          0         0         0
# 19114     -2     -2  ...          0          0          0         0         0
# 19487     -2     -2  ...          0          0          0         0         0
# 19604     -2     -2  ...          0          0          0         0         0
# 19897     -2     -2  ...          0          0          0         0         0
# 20875     -1     -1  ...        660        660        660       660       660
# 21881     -1     -1  ...        390        390        390       390       390
# 22162     -2     -2  ...          0          0          0         0         0
# 23877     -2     -2  ...          0          0          0         0         0
# 24122     -2     -2  ...          0          0          0         0         0
# 25608     -2     -2  ...          0          0          0         0         0
# 26249     -2     -2  ...          0          0          0         0         0
# 26805     -2     -2  ...          0          0          0         0         0
# 27351     -1     -1  ...       1443       1443       1443      1443      1443
# 27765     -2     -2  ...          0          0          0         0         0
# 27928     -2     -2  ...          0          0          0         0         0
# 27966     -2     -2  ...          0          0          0         0         0
# 28228     -2     -2  ...          0          0          0         0         0
# 28779     -2     -2  ...          0          0          0         0         0
# 28983     -2     -2  ...          0          0          0         0         0
# 29265     -1     -1  ...        396        396        396       396       396
# 29823     -2     -2  ...          0          0          0         0         0
# 29909     -2     -2  ...          0          0          0         0         0
#
#        PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# 1980          0         0         0         0                     default
# 4585          0         0         0         0                 not default
# 6022          0         0         0         0                 not default
# 6466          0         0         0         0                 not default
# 7319          0         0         0         0                     default
# 8320          0         0         0         0                     default
# 10250         0         0         0         0                 not default
# 13106         0         0         0         0                 not default
# 14294         0         0         0         0                     default
# 15458         0         0         0         0                 not default
# 15617         0         0         0         0                 not default
# 15685         0         0         0         0                 not default
# 17032         0         0         0         0                 not default
# 19114         0         0         0         0                 not default
# 19487         0         0         0         0                 not default
# 19604         0         0         0         0                 not default
# 19897         0         0         0         0                 not default
# 20875       660       660       660       660                 not default
# 21881       390       390       390       390                 not default
# 22162         0         0         0         0                 not default
# 23877         0         0         0         0                 not default
# 24122         0         0         0         0                 not default
# 25608         0         0         0         0                     default
# 26249         0         0         0         0                 not default
# 26805         0         0         0         0                 not default
# 27351      1443      1443      1443      1443                 not default
# 27765         0         0         0         0                 not default
# 27928         0         0         0         0                 not default
# 27966         0         0         0         0                 not default
# 28228         0         0         0         0                 not default
# 28779         0         0         0         0                 not default
# 28983         0         0         0         0                 not default
# 29265       396       396       396       396                 not default
# 29823         0         0         0         0                     default
# 29909         0         0         0         0                 not default
#
# [35 rows x 24 columns]

# %%
rawData = rawData.drop_duplicates()
rawData.duplicated().any()
# Out:
# False

# %%
rawData.isnull().any()
# Out:
# LIMIT_BAL                     False
# SEX                           False
# EDUCATION                     False
# MARRIAGE                      False
# AGE                           False
# PAY_0                         False
# PAY_2                         False
# PAY_3                         False
# PAY_4                         False
# PAY_5                         False
# PAY_6                         False
# BILL_AMT1                     False
# BILL_AMT2                     False
# BILL_AMT3                     False
# BILL_AMT4                     False
# BILL_AMT5                     False
# BILL_AMT6                     False
# PAY_AMT1                      False
# PAY_AMT2                      False
# PAY_AMT3                      False
# PAY_AMT4                      False
# PAY_AMT5                      False
# PAY_AMT6                      False
# default payment next month    False
# dtype: bool

# %%
#pd.get_dummies(Credit) turns Objects to uint8. Want to convert object to Category
##1. Convert Categorical Object datatypes to numerical datatypes
### 2. Will need to convert objects to categories first
rawData['SEX'] = rawData['SEX'].astype('category')
rawData['EDUCATION'] = rawData['EDUCATION'].astype('category')
# Out:
# C:\anaconda\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# C:\anaconda\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
#### 3. Assign each category lable a numeric value and store in a different column
rawData = rawData.assign(SEX_ID = rawData['SEX'].cat.codes)
rawData = rawData.assign(EDUCATION_ID = rawData['EDUCATION'].cat.codes)

# %%
rawData['default payment next month'] = rawData['default payment next month'].astype('category')

# %%
#### 3. Assign each category lable a numeric value and store in a different column
rawData = rawData.assign(Payment_Default_ID = rawData['default payment next month'].cat.codes)

# %%
rawData
# Out:
#        LIMIT_BAL     SEX    EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 0          20000  female   university         1   24      2      2     -1
# 1         120000  female   university         2   26     -1      2      0
# 2          90000  female   university         2   34      0      0      0
# 3          50000  female   university         1   37      0      0      0
# 4          50000    male   university         1   57     -1      0     -1
# ...          ...     ...          ...       ...  ...    ...    ...    ...
# 29995     220000    male  high school         1   39      0      0      0
# 29996     150000    male  high school         2   43     -1     -1     -1
# 29997      30000    male   university         2   37      4      3      2
# 29998      80000    male  high school         1   41      1     -1      0
# 29999      50000    male   university         1   46      0      0      0
#
#        PAY_4  PAY_5  ...  PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  \
# 0         -1     -2  ...         0       689         0         0         0
# 1          0      0  ...         0      1000      1000      1000         0
# 2          0      0  ...      1518      1500      1000      1000      1000
# 3          0      0  ...      2000      2019      1200      1100      1069
# 4          0      0  ...      2000     36681     10000      9000       689
# ...      ...    ...  ...       ...       ...       ...       ...       ...
# 29995      0      0  ...      8500     20000      5003      3047      5000
# 29996     -1      0  ...      1837      3526      8998       129         0
# 29997     -1      0  ...         0         0     22000      4200      2000
# 29998      0      0  ...     85900      3409      1178      1926     52964
# 29999      0      0  ...      2078      1800      1430      1000      1000
#
#        PAY_AMT6  default payment next month  SEX_ID  EDUCATION_ID  \
# 0             0                     default       0             3
# 1          2000                     default       0             3
# 2          5000                 not default       0             3
# 3          1000                 not default       0             3
# 4           679                 not default       1             3
# ...         ...                         ...     ...           ...
# 29995      1000                 not default       1             1
# 29996         0                 not default       1             1
# 29997      3100                     default       1             3
# 29998      1804                     default       1             1
# 29999      1000                     default       1             3
#
#        Payment_Default_ID
# 0                       0
# 1                       0
# 2                       1
# 3                       1
# 4                       1
# ...                   ...
# 29995                   1
# 29996                   1
# 29997                   0
# 29998                   0
# 29999                   0
#
# [29965 rows x 27 columns]

# %%
rawData.dtypes
# Out:
# LIMIT_BAL                        int64
# SEX                           category
# EDUCATION                     category
# MARRIAGE                         int64
# AGE                              int64
# PAY_0                            int64
# PAY_2                            int64
# PAY_3                            int64
# PAY_4                            int64
# PAY_5                            int64
# PAY_6                            int64
# BILL_AMT1                        int64
# BILL_AMT2                        int64
# BILL_AMT3                        int64
# BILL_AMT4                        int64
# BILL_AMT5                        int64
# BILL_AMT6                        int64
# PAY_AMT1                         int64
# PAY_AMT2                         int64
# PAY_AMT3                         int64
# PAY_AMT4                         int64
# PAY_AMT5                         int64
# PAY_AMT6                         int64
# default payment next month    category
# SEX_ID                            int8
# EDUCATION_ID                      int8
# Payment_Default_ID                int8
# dtype: object

# %%
#Need to convert new columns into numerical data (Int64)
rawData['SEX_ID'] = rawData['SEX_ID'].astype('int64')
rawData['EDUCATION_ID'] = rawData['EDUCATION_ID'].astype('int64')
rawData['Payment_Default_ID'] = rawData['Payment_Default_ID'].astype('int64')

# %%
rawData.dtypes
# Out:
# LIMIT_BAL                        int64
# SEX                           category
# EDUCATION                     category
# MARRIAGE                         int64
# AGE                              int64
# PAY_0                            int64
# PAY_2                            int64
# PAY_3                            int64
# PAY_4                            int64
# PAY_5                            int64
# PAY_6                            int64
# BILL_AMT1                        int64
# BILL_AMT2                        int64
# BILL_AMT3                        int64
# BILL_AMT4                        int64
# BILL_AMT5                        int64
# BILL_AMT6                        int64
# PAY_AMT1                         int64
# PAY_AMT2                         int64
# PAY_AMT3                         int64
# PAY_AMT4                         int64
# PAY_AMT5                         int64
# PAY_AMT6                         int64
# default payment next month    category
# SEX_ID                           int64
# EDUCATION_ID                     int64
# Payment_Default_ID               int64
# dtype: object

# %%
#features
X = rawData.loc[:, ['LIMIT_BAL','MARRIAGE','AGE','SEX_ID','EDUCATION_ID']]
print('Summary of feature sample')
X.head()
# Out:
# Summary of feature sample
#    LIMIT_BAL  MARRIAGE  AGE  SEX_ID  EDUCATION_ID
# 0      20000         1   24       0             3
# 1     120000         2   26       0             3
# 2      90000         2   34       0             3
# 3      50000         1   37       0             3
# 4      50000         1   57       1             3

# %%
#dependent variable
y = rawData['Payment_Default_ID']

# %%
from sklearn.linear_model import LinearRegression

# %%
#Tuning paramaters
model = LinearRegression(n_jobs=10)

# %%
rawData.to_csv('C:\\Users\\PLZ1669\\Desktop\\Data Analytics Certificate Program\\Course Two\\Task 3\Credit Risk Data 4.csv')

# %%
rawData = pd.read_csv('Credit Risk Data 4.csv')
rawData.dtypes
# Out:
# Unnamed: 0                     int64
# LIMIT_BAL                      int64
# SEX                           object
# EDUCATION                     object
# MARRIAGE                       int64
# AGE                            int64
# PAY_0                          int64
# PAY_2                          int64
# PAY_3                          int64
# PAY_4                          int64
# PAY_5                          int64
# PAY_6                          int64
# BILL_AMT1                      int64
# BILL_AMT2                      int64
# BILL_AMT3                      int64
# BILL_AMT4                      int64
# BILL_AMT5                      int64
# BILL_AMT6                      int64
# PAY_AMT1                       int64
# PAY_AMT2                       int64
# PAY_AMT3                       int64
# PAY_AMT4                       int64
# PAY_AMT5                       int64
# PAY_AMT6                       int64
# default payment next month    object
# SEX_ID                         int64
# EDUCATION_ID                   int64
# Payment_Default_ID             int64
# dtype: object

# %%
#Update features data types from object to category
rawData['SEX'] = rawData['SEX'].astype('category')
rawData['EDUCATION'] = rawData['EDUCATION'].astype('category')
rawData['default payment next month'] = rawData['default payment next month'].astype('category')

# %%
rawData.dtypes
# Out:
# Unnamed: 0                       int64
# LIMIT_BAL                        int64
# SEX                           category
# EDUCATION                     category
# MARRIAGE                         int64
# AGE                              int64
# PAY_0                            int64
# PAY_2                            int64
# PAY_3                            int64
# PAY_4                            int64
# PAY_5                            int64
# PAY_6                            int64
# BILL_AMT1                        int64
# BILL_AMT2                        int64
# BILL_AMT3                        int64
# BILL_AMT4                        int64
# BILL_AMT5                        int64
# BILL_AMT6                        int64
# PAY_AMT1                         int64
# PAY_AMT2                         int64
# PAY_AMT3                         int64
# PAY_AMT4                         int64
# PAY_AMT5                         int64
# PAY_AMT6                         int64
# default payment next month    category
# SEX_ID                           int64
# EDUCATION_ID                     int64
# Payment_Default_ID               int64
# dtype: object

# %%
#2 -Build three Regression models and choose the right one for our needs...cont on new notebook per POA
